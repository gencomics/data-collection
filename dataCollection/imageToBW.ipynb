# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
# try:
#   %tensorflow_version 2.x
# except Exception:
#   pass

# %%
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
tf.__version__

# %%
#To generate gifs
# !pip install imageio

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
from IPython import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# "/content/drive/My Drive/Colab Notebooks/Untitled0.ipynb"
# Out:
# Untitled0.ipynb

# %%
# !ls "/content/drive/My Drive/garfield/1978/August"
# Out:
# ga780801.gif  ga780808.gif  ga780815.gif  ga780822.gif	ga780829.gif
# ga780802.gif  ga780809.gif  ga780816.gif  ga780823.gif	ga780830.gif
# ga780803.gif  ga780810.gif  ga780817.gif  ga780824.gif	ga780831.gif
# ga780804.gif  ga780811.gif  ga780818.gif  ga780825.gif
# ga780805.gif  ga780812.gif  ga780819.gif  ga780826.gif
# ga780806.gif  ga780813.gif  ga780820.gif  ga780827.gif
# ga780807.gif  ga780814.gif  ga780821.gif  ga780828.gif

# %%
# !pip install python-resize-image

# %%
from os import listdir
from numpy import asarray
from numpy import vstack
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed
import os
from PIL import Image 
from resizeimage import resizeimage
 
# load all images in a directory into memory
def load_images(path, path2, size=(256,768)):
  src_list, tar_list,image3_list = list(), list(),list()
  for r, d, f in os.walk(path):
    print('r: ', r)
    print('d: ', d)
    print('f: ', f)
    for file in f:
      if '.gif' in file:
        # convertToBW(file)
        # print('file: ', file)
        # print('path: ', path)
        if os.path.isfile(r+"/"+file) and not file.startswith('.'):
          # Converting image to black and white
          image_file = Image.open(r+"/"+file) # open colour image
          # cover = resizeimage.resize_cover(image_file, [200, 100])
          image_file = image_file.convert('1') # convert image to black and white
          image_file.save(path2+file, image_file.format)
  return asarray(src_list)
 
# dataset path
path = "/content/drive/My Drive/garfield/"
path2 = "/content/drive/My Drive/garfieldbw/"
# load and convert datasets
src_images= load_images(path,path2)
print('SRC images : {}'.format(src_images))
train_images = src_images
#(train_images,train_labels),(_,_)= tf.keras.datasets.mnist.load_data()
print(src_images.shape)
# Out:
# r:  /content/drive/My Drive/garfield/
# d:  ['1981', '2015', '2014', '1987', '2012', '1986', '1980', '1988', '1989', '2013', '1993', '1994', '2008', '2000', '2007', '2006', '1992', '2009', '2001', '2017', '1995', '2010', '2019', '2020', '2018', '2011', '2016', '1985', '1984', '1978', '1979', '1982', '1983', '1997', '2002', '2004', '1990', '2005', '1998', '1999', '1991', '1996', '2003']
# f:  ['.DS_Store']
# r:  /content/drive/My Drive/garfield/1981
# d:  ['June', 'November', 'April', 'December', 'February', 'October', 'July', 'August', 'May', 'January', 'March', 'September']
# f:  []
# r:  /content/drive/My Drive/garfield/1981/June
# d:  []
# ...
